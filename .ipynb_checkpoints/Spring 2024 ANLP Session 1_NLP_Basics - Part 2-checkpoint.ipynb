# %% [markdown]
# # tinyurl.com/ANLPcolab1part2
#
#
# Go to "File" -> "Save a Copy in Drive..."
# This lets you create your own copy of the notebook in your Google drive, and any changes you make doesn't impact the shared notebook

# %% [markdown]
# ## Basic text analysis using Python

# %% [markdown]
# The first step is to install the required libraries using the pip command (if you don't have them), and import the modules from the libraries.

# %%
#Enable plots to be displayed in the notebook
# %matplotlib inline

# !pip install seaborn

import pandas as pd
import seaborn as sns
import nltk
from nltk.tokenize import word_tokenize
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Requirement already satisfied: seaborn in /Users/rodzaraya/opt/anaconda3/lib/python3.9/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /Users/rodzaraya/opt/anaconda3/lib/python3.9/site-packages (from seaborn) (1.24.3)
# Requirement already satisfied: pandas>=1.2 in /Users/rodzaraya/opt/anaconda3/lib/python3.9/site-packages (from seaborn) (2.0.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /Users/rodzaraya/opt/anaconda3/lib/python3.9/site-packages (from seaborn) (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/rodzaraya/opt/anaconda3/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/rodzaraya/opt/anaconda3/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/rodzaraya/opt/anaconda3/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/rodzaraya/opt/anaconda3/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/rodzaraya/opt/anaconda3/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/rodzaraya/opt/anaconda3/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/rodzaraya/opt/anaconda3/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/rodzaraya/opt/anaconda3/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/rodzaraya/opt/anaconda3/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (6.1.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/rodzaraya/opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/rodzaraya/opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: zipp>=3.1.0 in /Users/rodzaraya/opt/anaconda3/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn) (3.11.0)
# Requirement already satisfied: six>=1.5 in /Users/rodzaraya/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# WARNING: There was an error checking the latest version of pip.
# [nltk_data] Downloading package punkt to /Users/rodzaraya/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/rodzaraya/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# ## Mounting the drive
#
# In this notebook, I'm mounting the Google drive to read a csv file that is stored on my drive. You must allow access to your drive by signing in to your Google account.

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %% [markdown]
# Download the dataset from here: https://drive.google.com/file/d/1qAC9x-WMwzofyG8l1fFUoHwWhk3n61fp/view?usp=sharing
#
# Then, copy it to your Google drive folder which contains the notebook

# %%
# After executing the cell above, Drive files will be present in "/content/drive/My Drive". The below command lists the contents in the drive:
#!ls "/content/drive/MyDrive/CNN_Articles_2021-2023.csv"
#/content/drive/MyDrive/CNN_Articles_2021-2023.csv

# %% [markdown]
# ## Reading Data from a CSV File
#
# To read the data from the input csv file from my Google drive and store it as a Python dataframe, I use the read_csv() function from Pandas. You have to change the folder location to where the file is stored in your own Gdrive - mine is in this path:
# /content/drive/My Drive/Colab Notebooks/ANLP 2024 Colab Notebooks/CNN_Articles_2021-2023.csv
#
# You can read about the different functions and their input parameters in the  documentation for the library:
# [Pandas Documentation](http://pandas.pydata.org/pandas-docs/stable/)
#
# **Note:** Comment code below if you are not importing from your Gdrive folder

# %%
#The input csv file is a subset of the data from https://github.com/hadasu/CNN_web_crawler
newsdf = pd.read_csv('01_2021.csv',encoding='unicode_escape')

# %% [markdown]
# ## Reading input file from a url
# The alternative option is to read in the CSV from a web url (on github) and store it in a dataframe. This is a smaller dataset containing articles only from 2021 January to March.

# %%
url = 'https://github.com/AntonetteShibani/NLPAnalysis/blob/main/CNN_Articles_2021.csv?raw=true'
newsdf = pd.read_csv(url)

# %% [markdown]
# ## Preliminary data inspection
#
# We usually try to get a a sense of the data first (particularly useful for large data sets where opening in other UI based tools is not easy)

# %%
#Print general information about a DataFrame including the index dtype and columns, non-null values and memory usage
newsdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1708 entries, 0 to 1707
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            1708 non-null   int64
#  1   author                1708 non-null   object
#  2   date_published        1708 non-null   object
#  3   part_of               1708 non-null   object
#  4   article_section       1708 non-null   object
#  5   url                   1708 non-null   object
#  6   headline              1708 non-null   object
#  7   description           1708 non-null   object
#  8   keywords              1708 non-null   object
#  9   alternative_headline  1708 non-null   object
#  10  text                  1708 non-null   object
# dtypes: int64(1), object(10)
# memory usage: 146.9+ KB

# %%
newsdf.rename(columns={'Unnamed: 0': 'ID'}, inplace=True)

# %%
#Generate descriptive statistics that summarizes the central tendency, dispersion and shape of a dataset’s distribution
newsdf.describe()
# Out:
#                  ID
# count   1708.000000
# mean   20285.044496
# std    16894.328739
# min      157.000000
# 25%     5544.250000
# 50%    10812.500000
# 75%    41309.250000
# max    43956.000000

# %%
# Use the .head(n) function to look at the first 'n' rows of our news dataframe. The default n is 5, we are now changing it to view the first 10 rows
newsdf.head(10)
# Out:
#     ID                                             author
# 0  157                       Analysis by Daniel Dale, CNN  \
# 1  371                                    Ben Church, CNN
# 2  377                                    Ben Church, CNN
# 3  399                                    Ben Church, CNN
# 4  480                                Ashley Vaughan, CNN
# 5  510                            Samantha Bresnahan, CNN
# 6  511             Aisha Salaudeen and Robert Howell, CNN
# 7  548                   Jennifer Gray, CNN Meteorologist
# 8  567  Story by Drew Kann. Graphics by Renée Rigdon, CNN
# 9  569          Megan Alldridge and Stefanie Blendis, CNN
#
#               date_published   part_of article_section
# 0  2021-03-03 01:33:41+00:00  politics        politics  \
# 1  2021-03-19 10:23:09+00:00     sport           sport
# 2  2021-02-02 09:28:27+00:00     sport           sport
# 3  2021-03-12 11:59:44+00:00     sport           sport
# 4  2021-03-05 20:04:31+00:00      news              us
# 5  2021-03-08 02:09:30+00:00      news          africa
# 6  2021-01-08 09:09:05+00:00      news          africa
# 7  2021-02-08 18:44:27+00:00      news         weather
# 8  2021-02-22 10:45:53+00:00  business        business
# 9  2021-02-19 00:36:13+00:00      news           world
#
#                                                  url
# 0  https://www.cnn.com/2021/03/02/politics/fact-c...  \
# 1  https://www.cnn.com/2021/03/19/sport/black-ice...
# 2  https://www.cnn.com/2021/02/02/sport/slovenia-...
# 3  https://www.cnn.com/2021/03/12/sport/esports-l...
# 4  https://www.cnn.com/2021/03/05/us/how-to-suppo...
# 5  https://www.cnn.com/2021/03/07/africa/south-af...
# 6  https://www.cnn.com/2021/01/08/africa/nigeria-...
# 7  https://www.cnn.com/2021/02/08/weather/how-to-...
# 8  https://www.cnn.com/2021/02/22/business/flood-...
# 9  https://www.cnn.com/2021/02/18/world/erika-woo...
#
#                                             headline
# 0  Anatomy of a lie: How the myth that Antifa sto...  \
# 1  Black Ice film aiming to boost diversity in cl...
# 2  Slovenia chimney climb: Janja Garnbret and Dom...
# 3  Team Liquid: How esports has helped its fans g...
# 4  Attacks against Asian Americans are on the ris...
# 5  These women are shaping the future of African ...
# 6  Nigeria's 'techpreneurs' are using technology ...
# 7                  How to survive an avalanche - CNN
# 8  Climate change is increasing flood risk around...
# 9  Erika Woolsey and The Hydrous are using virtua...
#
#                                          description
# 0  Despite numerous debunkings, the lie that Anti...  \
# 1  Whether it's a comment about his hair or quest...
# 2  Climbers Janja Garnbret and Domen Škofic scale...
# 3  The return of sport amid the pandemic has been...
# 4  "We're just tired," Will Lex Ham of New York C...
# 5  In celebration of International Women's Day, m...
# 6  Meet the startup founders from Co-Creation Hub...
# 7  Avalanches can occur any month of the year and...
# 8  Flooding is the most costly natural disaster i...
# 9  Marine biologist Erika Woolsey is using immers...
#
#                                             keywords
# 0  politics, Anatomy of a lie: How the myth that ...  \
# 1  sport, Black Ice film aiming to boost diversit...
# 2  sport, Slovenia chimney climb: Janja Garnbret ...
# 3  sport, Team Liquid: How esports has helped its...
# 4  us, Attacks against Asian Americans are on the...
# 5  africa, These women are shaping the future of ...
# 6  africa, Nigeria's 'techpreneurs' are using tec...
# 7         weather, How to survive an avalanche - CNN
# 8  business, Climate change is increasing flood r...
# 9  world, Erika Woolsey and The Hydrous are using...
#
#                                 alternative_headline
# 0  Anatomy of a lie: How the myth that Antifa sto...  \
# 1  'It was super cool just having that much melan...
# 2  'The most special thing I've done': Two world-...
# 3  'They are like a family': How esports has help...
# 4  Attacks against Asian Americans are on the ris...
# 5  These women are shaping the future of African ...
# 6  Nigeria's 'techpreneurs' are using technology ...
# 7  How to avoid avalanches and what to do if you'...
# 8  Flood risk is growing for US homeowners due to...
# 9  A marine biologist is using virtual reality to...
#
#                                                 text
# 0  Washington (CNN)FBI Director Christopher Wray ...
# 1   (CNN)Whether it's a comment about his hair or...
# 2   (CNN)Soaring 360 meters into the sky, the Trb...
# 3   (CNN)The return of sport amid the pandemic ha...
# 4   (CNN)"We're just tired," Will Lex Ham of New ...
# 5   (CNN)In the heart of Cape Town, a control roo...
# 6  Lagos, Nigeria (CNN)As recently as 10 years ag...
# 7   (CNN)It has been a deadly week in the US from...
# 8   (CNN)Wildfires and hurricane-force winds prod...
# 9   (CNN)Diving in the oceans, marine biologist E...

# %%
#A function similar to above, but provides a random sample of rows rather than the first few.
newsdf.sample(5)
# Out:
#          ID                                     author
# 1625  41675                           Story by Reuters  \
# 98     2772        Opinion by Lisa Respers France, CNN
# 1022  15856              Analysis by Richard Roth, CNN
# 1159  41186                          John Sinnott, CNN
# 9       569  Megan Alldridge and Stefanie Blendis, CNN
#
#                  date_published part_of article_section
# 1625  2021-03-11 13:58:26+00:00   sport          tennis  \
# 98    2021-03-05 11:19:35+00:00    news        opinions
# 1022  2021-03-11 03:29:02+00:00    news           world
# 1159  2021-01-17 16:24:19+00:00   sport           sport
# 9     2021-02-19 00:36:13+00:00    news           world
#
#                                                     url
# 1625  https://www.cnn.com/2021/03/11/tennis/tennis-s...  \
# 98    https://www.cnn.com/2021/03/05/opinions/father...
# 1022  https://www.cnn.com/2021/03/10/world/myanmar-u...
# 1159  https://www.cnn.com/2021/01/17/sport/americas-...
# 9     https://www.cnn.com/2021/02/18/world/erika-woo...
#
#                                                headline
# 1625  Tennis counts the cost of empty stands: 'We ca...  \
# 98    Opinion: As you celebrate pandemic hope on the...
# 1022  The diplomacy behind the scenes of the UN Secu...
# 1159  America's Cup: Patriot 'flying yacht' capsizes...
# 9     Erika Woolsey and The Hydrous are using virtua...
#
#                                             description
# 1625  Tennis has limped back to some semblance of no...  \
# 98    Lisa Respers France writes that after losing h...
# 1022  Security Council 101 on Myanmar: We don't get ...
# 1159  Emergency management plans were put into opera...
# 9     Marine biologist Erika Woolsey is using immers...
#
#                                                keywords
# 1625  tennis, Tennis counts the cost of empty stands...  \
# 98    opinions, Opinion: As you celebrate pandemic h...
# 1022  world, The diplomacy behind the scenes of the ...
# 1159  sport, America's Cup: Patriot 'flying yacht' c...
# 9     world, Erika Woolsey and The Hydrous are using...
#
#                                    alternative_headline
# 1625  'We cannot survive', tennis counts the cost of...  \
# 98    As you celebrate pandemic hope on the horizon,...
# 1022  The diplomacy behind the scenes of the UN Secu...
# 1159  America's Cup: Patriot 'flying yacht' capsizes...
# 9     A marine biologist is using virtual reality to...
#
#                                                    text
# 1625  Tennis has limped back to some semblance of no...
# 98    Lisa Respers France is a senior writer for CNN...
# 1022   (CNN)Security Council 101 on Myanmar: We don'...
# 1159   (CNN)Emergency management plans were put into...
# 9      (CNN)Diving in the oceans, marine biologist E...

# %% [markdown]
# ## Word Count
#
# Word counts are simple but useful indicators for asking questions on the length of texts.
#
# To demonstrate usage, we see how the metrics are calculated for one sample sentence from the dataset.

# %%
s = newsdf['headline'][2]
print(s)

#Splitting by whitespace characters and calculating the length. Note that punctuation marks are also counted as words
len(s.split())
# Out:
# Slovenia chimney climb: Janja Garnbret and Domen Škofic scale the world's tallest artificial multi-pitch route - CNN
# 17

# %%
#To make it easier to reuse in the future, we can create a function that returns word count
def word_count(text):
    wc = len(text.split())
    return wc

# %% [markdown]
# Now now we can apply the word_count function to our text variable to create a new variable with the number of words in the news article text.

# %%
newsdf['article_word_count'] = newsdf['text'].apply(word_count)

# %% [markdown]
# We can use describe, hist, and scatter functions to provide some information on the length of articles in our dataset

# %%
newsdf['article_word_count'].describe()
# Out:
# count    1708.000000
# mean     1026.977752
# std       657.996654
# min        48.000000
# 25%       589.750000
# 50%       909.000000
# 75%      1267.750000
# max      7977.000000
# Name: article_word_count, dtype: float64

# %%
newsdf['article_word_count'].hist(bins = 10)
# Out:
# <Axes: >

# %%
sns.boxplot(x = "part_of",
            y = "article_word_count",
            palette='Set3',
            data =newsdf);
# Out:
# /var/folders/nq/qwlbc_5113zc0kcq7gz5hhpr0000gn/T/ipykernel_7585/2046507628.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x = "part_of",

# %%
#I'm using a function that populates bar graph from a dataframe variable
import matplotlib.pyplot as plt
from collections import Counter
from nltk.corpus import stopwords

def wordBarGraphFunction(df,column,title):
    topic_words = [ z.lower() for y in
                       [ x.split() for x in df[column] if isinstance(x, str)]
                       for z in y]
    word_count_dict = dict(Counter(topic_words))
    popular_words = sorted(word_count_dict, key = word_count_dict.get, reverse = True)
    popular_words_nonstop = [w for w in popular_words if w not in stopwords.words("english")]
    plt.barh(range(50), [word_count_dict[w] for w in reversed(popular_words_nonstop[0:50])])
    plt.yticks([x + 0.5 for x in range(50)], reversed(popular_words_nonstop[0:50]))
    plt.title(title)
    plt.show()

# %%
plt.figure(figsize=(10,10))
wordBarGraphFunction(newsdf,'headline',"Most frequent words in news article headlines (Jan-Mar 2021)")

# %% [markdown]
# We can further explore the articles which are of the longest and shortest lengths

# %%
#shortest
newsdf.sort_values(by='article_word_count').head(10)
# Out:
#          ID                              author             date_published
# 1006  15387                                 CNN  2021-01-13 01:57:09+00:00  \
# 1567  sport, Timur Faizutdinov: Russian hockey playe...
# 1004  politics, READ: President Joe Biden's schedule...
#
#                                    alternative_headline
# 1006  READ: Mike Pence's letter to Nancy Pelosi sayi...  \
# 1008  READ: Ruling dismissing Gohmert's lawsuit agai...
# 1005  These 10 House Republicans voted to impeach Tr...
# 1003  Read: Former President Donald Trump's January ...
# 150   Read: Former President Donald Trump's January ...
# 978   French politician Olivier Dassault dies in hel...
# 1459  After over a year out due to injury, Roger Fed...
# 1292      Czech free-diver breaks ice-swim world record
# 1567  Russian hockey player Timur Faizutdinov, 19, d...
# 1004  READ: President Joe Biden's schedule for his f...
#
#                                                    text  article_word_count
# 1006   (CNN)Vice President Mike Pence wrote in a new...                  48
# 1008   (CNN)Federal Judge Jeremy Kernodle on Friday ...                  48
# 1005   (CNN)The House of Representatives voted to im...                  71
# 1003   (CNN)Former President Donald Trump gave a Jan...                  77
# 150    (CNN)Former President Donald Trump gave a Jan...                  77
# 978    (CNN)French politician Olivier Dassault has d...                  88
# 1459   (CNN)Roger Federer will make his long-awaited...                 121
# 1292  Czech free-diver David Vencl swam nearly 81 me...                 123
# 1567   (CNN)A 19-year-old Russian hockey player has ...                 127
# 1004   (CNN)President Joe Biden's first full day in ...                 134

# %%
#longest
newsdf.sort_values(by='article_word_count', ascending=False).head(10)
# Out:
#          ID                                             author
# 921   12548                                 Nicole Chavez, CNN  \
# 211    3234  Opinion by Jhodie-Ann Williams and Jane Greenw...
# 405    5520  Opinion by Jhodie-Ann Williams and Jane Greenw...
# 604    7304  Opinion by Jhodie-Ann Williams and Jane Greenw...
# 770    9313  Opinion by Jhodie-Ann Williams and Jane Greenw...
# 854   10813                                   Thomas Page, CNN
# 973   14088            Esha Mitra and Julia Hollingsworth, CNN
# 1018  15718  Sandi Sidhu, Helen Regan, Ivan Watson and Sala...
# 1019  15719  Helen Regan, Sandi Sidhu, Paula Hancocks and S...
# 477    6063  Daniel Dale, Holmes Lybrand and Tara Subramani...
#
#                  date_published   part_of article_section
# 921   2021-01-08 22:47:18+00:00      news              us  \
# 211   2021-02-06 15:04:20+00:00      news        opinions
# 405   2021-02-06 15:04:20+00:00      news        opinions
# 604   2021-02-06 15:04:20+00:00      news        opinions
# 770   2021-02-06 15:04:20+00:00      news        opinions
# 854   2021-02-23 12:02:13+00:00      news           world
# 973   2021-02-26 00:14:06+00:00      news            asia
# 1018  2021-03-13 00:27:33+00:00      news            asia
# 1019  2021-03-05 08:14:13+00:00      news            asia
# 477   2021-02-23 15:02:38+00:00  politics        politics
#
#                                                     url
# 921   https://www.cnn.com/2021/01/08/us/police-respo...  \
# 211   https://www.cnn.com/2021/02/06/opinions/covid-...
# 405   https://www.cnn.com/2021/02/06/opinions/covid-...
# 604   https://www.cnn.com/2021/02/06/opinions/covid-...
# 770   https://www.cnn.com/2021/02/06/opinions/covid-...
# 854   https://www.cnn.com/2021/02/23/world/life-in-a...
# %% [markdown]
# You can then examine the content of individual articles to gain additional insight as needed.

# %% [markdown]
# ## Word frequencies
#
# Word frequencies (counting how often words occur) is a critical step in quantifying texts for many kinds of text analysis. There are inbuilt functions in Python that can compute words frequencies.
#
# Note that this analysis disregards the word order in the original sentence, taking a bag-of-words approach.

# %% [markdown]
# Calculate frequencies to determine the most common words in the corpus

# %%
# converting series to string
article_text = newsdf['text'].to_string()

#create word tokens
tokenized_words=word_tokenize(article_text)

# %%
all_words=nltk.FreqDist(tokenized_words)
all_words.plot(10);
print(all_words.most_common(20))
# Out:
# [('...', 1707), ('CNN', 1190), ('(', 1136), (')', 1136), ('a', 573), ('is', 517), ('the', 469), (',', 393), ('of', 319), ('and', 216), ('The', 178), ('in', 171), ("'s", 154), ('has', 128), ('to', 113), ('London', 110), ('.', 84), ('A', 82), ('former', 80), ('who', 74)]

# %% [markdown]
# Create a word cloud to show most common words in the article text.
#
# Note: There are so many ways in which you can customise word clouds for display, check out the documentation and read related blogs posts to try different combinations.

# %%
from wordcloud import WordCloud
wordcloud = WordCloud(max_words=100).generate(article_text)

import matplotlib.pyplot as plt
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# You will notice that the most frequent terms are stopwords and punctuations, let's try recalculating frequencies after performing some basic cleaning.

# %%
# converting article text to lowercase as Python is case-sensitive
article_text_lower = article_text.lower()

#create word tokens
tokenized_words=word_tokenize(article_text_lower)

#Set up stop words for removal
nltk.download('stopwords')
from nltk.corpus import stopwords
#stopwords
stop_words=stopwords.words("english")
print(stop_words)
#Add custom stopwords to the list
stop_words.extend(["cnn", "'s", "a", "the"])
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/rodzaraya/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#Create a new variable to store filtered tokens
filtered_tokens=[]
for w in tokenized_words:
    if w not in stop_words:
         #add all filtered tokens excluding stopwords in this list below
         filtered_tokens.append(w)

import string
# punctuations
punctuations=list(string.punctuation)
#Add custom punctuations to the list
punctuations.append("...")

#Create another variable to store all clean tokens
filtered_tokens_clean=[]
for i in filtered_tokens:
    if i not in punctuations:
        filtered_tokens_clean.append(i)

# %% [markdown]
# Now that we have cleaned the input text, let's calculate frequencies again to view the most common words.

# %%
all_words=nltk.FreqDist(filtered_tokens_clean)
all_words.plot(10);
print(all_words.most_common(20))
# Out:
# [('london', 110), ('former', 94), ('president', 71), ('new', 70), ('``', 66), ('analyst', 51), ("''", 46), ('us', 45), ('trump', 45), ('author', 37), ('writer', 36), ('journalist', 36), ('legal', 35), ('washington', 34), ('political', 33), ('director', 31), ('business', 29), ('senior', 29), ('professor', 28), ('n', 27)]

# %%
#FIX
# Ensure filtered_tokens_clean is a list of words, then join them into a single string
text = ' '.join(filtered_tokens_clean)

wordcloud = WordCloud(max_words=100).generate(text)

import matplotlib.pyplot as plt
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
#filtered_tokens_clean

# %% [markdown]
# Exercise: What are the insights from here? What do the key words indicate?

# %% [markdown]
# Certainly the cleaning words are more important that the uncleaned, since several words without any many are the most repeated. This new words can be found London, washington, so we can made an impresion about the place of the articles, and with the words legal, research, analyst, we can also can think about possible topics.
# However, there is a huge universe to discover.
